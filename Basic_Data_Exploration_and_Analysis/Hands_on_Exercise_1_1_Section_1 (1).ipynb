# %%
import pandas as pd
import matplotlib . pyplot as plt

# %%
# Initialize a dataframe
df = pd. DataFrame ({
'student_ID ': [1, 2, 3, 4],
'name ': ['Alice ', 'Bob ', 'Catherine ', 'David '],
'major ': ['CSC ', 'EE ', 'EDU ', 'CSC '],
'GPA ': [3.2, 3.8, 2.5, 3.9],
'classification ': ['Junior ', 'Senior ', 'Sophomore ', 'Freshman ']
})
df
# Out:
#    student_ID        name  major   GPA  classification
# 0            1      Alice    CSC    3.2         Junior
# 1            2        Bob     EE    3.8         Senior
# 2            3  Catherine    EDU    2.5      Sophomore
# 3            4      David    CSC    3.9       Freshman

# %%
print(df['name '])
# Out:
# 0        Alice
# 1          Bob
# 2    Catherine
# 3        David
# Name: name , dtype: object

# %%
print(df.columns)
# Out:
# Index(['student_ID ', 'name ', 'major ', 'GPA ', 'classification '], dtype='object')

# %%
# Plotting the distribution of Majors
df['major '].value_counts().plot(kind='bar')
plt.title('Distribution of Majors')
plt.xlabel('Major')
plt.ylabel('Count')
plt.show()

# %%
#Binary Attributes (0.2 points)

df['considering_graduate_school '] = ['Yes ', 'Yes ', 'No', 'No ']
df
# Out:
#    student_ID        name  major   GPA  classification   \
# 0            1      Alice    CSC    3.2         Junior
# 1            2        Bob     EE    3.8         Senior
# 2            3  Catherine    EDU    2.5      Sophomore
# 3            4      David    CSC    3.9       Freshman
#
#   considering_graduate_school
# 0                         Yes
# 1                         Yes
# 2                           No
# 3                          No

# %%
df['considering_graduate_school_binary '] = df['considering_graduate_school '].map({'No ': 0, 'Yes ': 1})
df
# Out:
#    student_ID        name  major   GPA  classification   \
# 0            1      Alice    CSC    3.2         Junior
# 1            2        Bob     EE    3.8         Senior
# 2            3  Catherine    EDU    2.5      Sophomore
# 3            4      David    CSC    3.9       Freshman
#
#   considering_graduate_school   considering_graduate_school_binary
# 0                         Yes                                   1.0
# 1                         Yes                                   1.0
# 2                           No                                  NaN
# 3                          No                                   0.0

# %%
print(df['classification '])
# Out:
# 0       Junior
# 1       Senior
# 2    Sophomore
# 3     Freshman
# Name: classification , dtype: object

# %%
classification_map = {'Freshman ': 1, 'Sophomore ': 2, 'Junior ': 3, 'Senior ': 4}
df['classification_ordinal '] = df['classification '].map(classification_map )
df
# Out:
#    student_ID        name  major   GPA  classification   \
# 0            1      Alice    CSC    3.2         Junior
# 1            2        Bob     EE    3.8         Senior
# 2            3  Catherine    EDU    2.5      Sophomore
# 3            4      David    CSC    3.9       Freshman
#
#   considering_graduate_school   considering_graduate_school_binary   \
# 0                         Yes                                   1.0
# 1                         Yes                                   1.0
# 2                           No                                  NaN
# 3                          No                                   0.0
#
#    classification_ordinal
# 0                        3
# 1                        4
# 2                        2
# 3                        1

# %%
print(df['GPA '])
# Out:
# 0    3.2
# 1    3.8
# 2    2.5
# 3    3.9
# Name: GPA , dtype: float64
