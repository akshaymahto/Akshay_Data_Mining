# %%
from google.colab import drive
import pandas as pd
import matplotlib.pyplot as plt
# Mount Google Drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv('/content/drive/MyDrive/Data Mining 2025/geolocation.csv')

# Show the first few rows of the DataFrame
df.head ()
# Out:
#   truckid driverid      event   latitude   longitude        city       state  \
# 0     A54      A54     normal  38.440467 -122.714431  Santa Rosa  California
# 1     A20      A20     normal  36.977173 -121.899402       Aptos  California
# 2     A40      A40  overspeed  37.957702 -121.290780    Stockton  California
# 3     A31      A31     normal  39.409608 -123.355566     Willits  California
# 4     A71      A71     normal  33.683947 -117.794694      Irvine  California
#
#    velocity  event_ind  idling_ind
# 0        17          0           0
# 1        27          0           0
# 2        77          1           0
# 3        22          0           0
# 4        43          0           0

# %%
# Show data types and non -null counts
df.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   truckid     8000 non-null   object
#  1   driverid    8000 non-null   object
#  2   event       8000 non-null   object
#  3   latitude    8000 non-null   float64
#  4   longitude   8000 non-null   float64
#  5   city        8000 non-null   object
#  6   state       8000 non-null   object
#  7   velocity    8000 non-null   int64
#  8   event_ind   8000 non-null   int64
#  9   idling_ind  8000 non-null   int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 625.1+ KB

# %%
# Five Number Summary
df. describe ()
# Out:
#           latitude    longitude    velocity    event_ind   idling_ind
# count  8000.000000  8000.000000  8000.00000  8000.000000  8000.000000
# mean     37.128944  -118.629551    35.05650     0.056375     0.230375
# std       2.214427    16.004797    24.86375     0.230659     0.421099
# min      32.617680  -124.038407     0.00000     0.000000     0.000000
# 25%      34.579434  -122.524149    16.00000     0.000000     0.000000
# 50%      37.957702  -121.568275    37.00000     0.000000     0.000000
# 75%      38.693723  -119.018712    55.00000     0.000000     0.000000
# max      41.526509    -6.196595   100.00000     1.000000     1.000000

# %%
# Filter rows where event is not normal
unsafe_df = df[df['event'] != 'normal']
unsafe_df .head ()
# Out:
#    truckid driverid                      event   latitude   longitude  \
# 2      A40      A40                  overspeed  37.957702 -121.290780
# 12      A5       A5  unsafe following distance  41.526509 -124.038407
# 14     A48      A48                  overspeed  38.752124 -121.288006
# 22     A94      A94  unsafe following distance  37.941325 -122.484704
# 24     A49      A49             lane departure  39.150171 -123.207783
#
#            city       state  velocity  event_ind  idling_ind
# 2      Stockton  California        77          1           0
# 12      Klamath  California        33          1           0
# 14    Roseville  California        77          1           0
# 22  San Quentin  California         0          1           1
# 24        Ukiah  California        41          1           0

# %%
# Group by event type and count the number of occurrences
grouped_df = unsafe_df . groupby ('event'). count ()
grouped_df
# Out:
#                            truckid  driverid  latitude  longitude  city  \
# event
# lane departure                 152       152       152        152   152
# overspeed                       90        90        90         90    90
# unsafe following distance      150       150       150        150   150
# unsafe tail distance            65        65        65         65    65
#
#                            state  velocity  event_ind  idling_ind
# event
# lane departure               152       152        152         152
# overspeed                     90        90         90          90
# unsafe following distance    150       150        150         150
# unsafe tail distance          65        65         65          65

# %%
# Five Number Summary for the 'velocity ' column
df['velocity']. describe ()
# Out:
# count    8000.00000
# mean       35.05650
# std        24.86375
# min         0.00000
# 25%        16.00000
# 50%        37.00000
# 75%        55.00000
# max       100.00000
# Name: velocity, dtype: float64

# %%
min_value = df['velocity'].min ()
min_value
# Out:
# 0

# %%
Q1 = df['velocity']. quantile (0.25)
Q1
# Out:
# 16.0

# %%
median = df['velocity']. median ()
median
# Out:
# 37.0

# %%
Q3 = df['velocity']. quantile (0.75)
Q3
# Out:
# 55.0

# %%
max_value = df['velocity'].max ()
max_value
# Out:
# 100

# %%
five_num_summary = df['velocity']. describe ()[['min', '25%', '50%', '75%', 'max']]
five_num_summary
# Out:
# min      0.0
# 25%     16.0
# 50%     37.0
# 75%     55.0
# max    100.0
# Name: velocity, dtype: float64

# %%
# Read trucks .csv into df_trucks DataFrame
df_trucks = pd. read_csv ('/content/drive/MyDrive/Data Mining 2025/trucks.csv')
df_trucks
# Out:
#    driverid truckid         model  jun13_miles  jun13_gas  may13_miles  \
# 0        A1      A1  Freightliner         9217       1914         8769
# 1        A2      A2          Ford        12058       2335        14314
# 2        A3      A3          Ford        13652       2899        12075
# 3        A4      A4      Kenworth        12687       2439        10680
# 4        A5      A5          Hino        10233       1825        14634
# ..      ...     ...           ...          ...        ...          ...
# 95      A96     A96     Peterbilt        12738       2637        13991
# 96      A97     A97   Caterpillar        13489       2425        10189
# 97      A98     A98         Volvo        10732       2238        11661
# 98      A99     A99     Peterbilt        13912       2720        12916
# 99     A100    A100     Peterbilt        13019       2329        13991
#
#     may13_gas
# 0        1892
# 1        2648
# 2        2603
# 3        2083
# 4        3450
# ..        ...
# 95       2566
# 96       1862
# 97       2528
# 98       2529
# 99       2488
#
# [100 rows x 7 columns]

# %%
# Display first 5 rows and selected columns
df_trucks = df_trucks [['driverid', 'truckid', 'model', 'jun13_miles', 'jun13_gas', 'may13_miles', 'may13_gas']]
df_trucks .head(5)
# Out:
#   driverid truckid         model  jun13_miles  jun13_gas  may13_miles  \
# 0       A1      A1  Freightliner         9217       1914         8769
# 1       A2      A2          Ford        12058       2335        14314
# 2       A3      A3          Ford        13652       2899        12075
# 3       A4      A4      Kenworth        12687       2439        10680
# 4       A5      A5          Hino        10233       1825        14634
#
#    may13_gas
# 0       1892
# 1       2648
# 2       2603
# 3       2083
# 4       3450

# %%
# Group by model and count
model_count = df_trucks . groupby ('model'). count ()
model_count
11
# Out:
# 11

# %%
# Five Number Summary for mileage in June and May
df_trucks [['jun13_miles', 'may13_miles']]. describe ()
# Out:
#         jun13_miles   may13_miles
# count    100.000000    100.000000
# mean   12043.120000  12188.820000
# std     1777.444655   1931.169601
# min     8490.000000   8304.000000
# 25%    10669.500000  10460.000000
# 50%    12048.000000  12632.500000
# 75%    13533.000000  13727.750000
# max    15548.000000  15726.000000

# %%
# Five Number Summary for gas in June and May
df_trucks [['jun13_gas', 'may13_gas']]. describe ()
# Out:
#          jun13_gas    may13_gas
# count   100.000000   100.000000
# mean   2456.320000  2422.140000
# std     436.052075   414.699843
# min    1593.000000  1637.000000
# 25%    2091.000000  2076.500000
# 50%    2438.500000  2472.000000
# 75%    2744.750000  2749.500000
# max    3446.000000  3450.000000
